# %% [markdown]
# <a href="https://colab.research.google.com/github/Anudheer-AK/SE-TASK-2/blob/main/SE_task_program1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def agent(percept):
    room, status = percept
    if room == "A":
        if status == "Clean":
            return "Move to Right"
        elif status == "Dirty":
            return "Suck"
    elif room == "B":
        if status == "Clean":
            return "Move to Left"
        elif status == "Dirty":
            return "Suck"

def main():
    rooms = ["A", "B"]
    clean_status = ["Clean", "Dirty"]
    percept_table = {}

    while True:
        room = input("Enter the room (A/B) or type 'exit' to quit: ")
        if room.lower() == "exit":
            break
        status = input("Enter the cleanliness status (Clean/Dirty): ")

        room = room.upper()
        status = status.capitalize()

        if room not in rooms or status not in clean_status:
            print("Invalid Input!!")
            continue

        percept = (room, status)

        action = agent(percept)

        percept_table[percept] = action

        print("Action:", action)

    print("\nAGENT FUNCTION Percept-Action Table:")
    print("------------------------------------")
    for percept, action in percept_table.items():
        print(f"Percept: {percept}\t\tAction: {action}")

if __name__ == "__main__":
    main()
# Out:
# Enter the room (A/B) or type 'exit' to quit: b
# Enter the cleanliness status (Clean/Dirty): clean
# Action: Move to Left
# Enter the room (A/B) or type 'exit' to quit: b
# Enter the cleanliness status (Clean/Dirty): clean
# Action: Move to Left
# Enter the room (A/B) or type 'exit' to quit: exit
#
# AGENT FUNCTION Percept-Action Table:
# ------------------------------------
# Percept: ('B', 'Clean')		Action: Move to Left
