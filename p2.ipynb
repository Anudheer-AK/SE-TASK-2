# %% [markdown]
# <a href="https://colab.research.google.com/github/Anudheer-AK/SE-TASK-2/blob/main/p2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
c = float(input("Enter Celsius: "))
f = (c * 9/5) + 32
print("Fahrenheit =", f)
# Out:
# Enter Celsius: 3
# Fahrenheit = 37.4
