# %% [markdown]
# <a href="https://colab.research.google.com/github/Anudheer-AK/SE-TASK-2/blob/main/p14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = int(input("Enter number: "))
temp = n
digits = len(str(n))
s = 0
while temp > 0:
    d = temp % 10
    s += d ** digits
    temp //= 10
print("Armstrong" if s == n else "Not Armstrong")
# Out:
# Enter number: 10
# Not Armstrong
