# %% [markdown]
# <a href="https://colab.research.google.com/github/Anudheer-AK/SE-TASK-2/blob/main/p5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def go(m_pos, b_pos, m_vpos):
    if m_pos != b_pos and b_pos != "middle":
        m_pos = b_pos
        print("the monkey walked to the box which is at", b_pos)
        push(m_pos, b_pos, m_vpos)
    elif m_pos != b_pos and b_pos == "middle":
        m_pos = "middle"
        print()
        climb(m_pos, b_pos, m_vpos)
    else:
        push(m_pos, b_pos, m_vpos)

def push(m_pos, b_pos, m_vpos):
    m_pos = "middle"
    b_pos = "middle"
    print("the monkey has pushed the box to the middle" )
    climb(m_pos, b_pos, m_vpos)


def climb(m_pos, b_pos, m_vpos):
    if m_pos == "middle" and b_pos == "middle" and m_vpos == "floor":
        m_vpos = "on_box"
        print("the monkey has climbed on to the box")
    if m_vpos == "on_box":
        grasp(m_pos, b_pos, m_vpos)

def grasp(m_pos, b_pos, m_vpos):
    if m_pos == b_pos and m_vpos == "on_box":
        has_banana = True
        print(" The monkey has taken the banana")

m_pos = input("enter the pos of monkey (door/window/middle): ")
b_pos = input("enter the pos of box(door/window/middle): ")
print("the monkey is at", m_pos, "and the box is at", b_pos)
m_vpos = "floor"
has_banana = False
if m_pos != b_pos:
    go(m_pos, b_pos, m_vpos)
elif m_pos == b_pos and m_pos != "middle":
    push(m_pos, b_pos, m_vpos)
else:
    climb(m_pos, b_pos, m_vpos)
# Out:
# enter the pos of monkey (door/window/middle): window
# enter the pos of box(door/window/middle): middle
# the monkey is at window and the box is at middle
#
# the monkey has climbed on to the box
#  The monkey has taken the banana
