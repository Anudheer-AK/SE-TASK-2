# %% [markdown]
# <a href="https://colab.research.google.com/github/Anudheer-AK/SE-TASK-2/blob/main/p15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = int(input("Enter decimal: "))
if n == 0:
    print("Binary = 0")
else:
    b = ""
    while n > 0:
        b = str(n % 2) + b
        n //= 2
    print("Binary =", b)
# Out:
# Enter decimal: 4
# Binary = 100
