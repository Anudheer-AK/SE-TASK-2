# %% [markdown]
# <a href="https://colab.research.google.com/github/Anudheer-AK/SE-TASK-2/blob/main/p9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
arr = list(map(int, input("Enter numbers: ").split()))
arr = list(set(arr))
arr.sort()
if len(arr) < 2:
    print("No second largest")
else:
    print("Second largest =", arr[-2])
# Out:
# Enter numbers: 45
# No second largest
