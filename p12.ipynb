# %% [markdown]
# <a href="https://colab.research.google.com/github/Anudheer-AK/SE-TASK-2/blob/main/p12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
    n = int(input("Enter integer: "))
    print("Square =", n*n)
except:
    print("Invalid input")
# Out:
# Enter integer: 4
# Square = 16
